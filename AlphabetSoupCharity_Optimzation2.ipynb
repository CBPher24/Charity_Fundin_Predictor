# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Dropping the non-beneficial ID columns, 'EIN' and 'NAME'.
clean_data1 = application_df.drop(["EIN","NAME"], axis = 1)
clean_data1.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determining the number of unique values in each column.
clean_data1.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Looking at APPLICATION_TYPE value counts for binning
clean_data1["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
counter = clean_data1["APPLICATION_TYPE"].value_counts()
application_types_to_replace = counter[counter.lt(500)].index

# Replace in dataframe
for app in application_types_to_replace:
    clean_data1['APPLICATION_TYPE'] = clean_data1['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
clean_data1['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
clean_data1["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
C_counter = clean_data1["CLASSIFICATION"].value_counts()
C_counter[C_counter.gt(1)]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = C_counter[C_counter.lt(1800)].index

# Replace in dataframe
for cls in classifications_to_replace:
    clean_data1['CLASSIFICATION'] = clean_data1['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
clean_data1['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
clean_data2 = pd.get_dummies(clean_data1)

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = clean_data2["IS_SUCCESSFUL"].values
X = clean_data2.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=45)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="sigmoid"))

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 8)                 352
#
#  dense_4 (Dense)             (None, 5)                 45
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 403
# Trainable params: 403
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6408 - accuracy: 0.6626
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5787 - accuracy: 0.7291
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5732 - accuracy: 0.7294
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5716 - accuracy: 0.7306
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5703 - accuracy: 0.7310
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5689 - accuracy: 0.7313
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5670 - accuracy: 0.7308
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5651 - accuracy: 0.7311
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5631 - accuracy: 0.7314
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5614 - accuracy: 0.7316
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5601 - accuracy: 0.7317
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5589 - accuracy: 0.7322
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7322
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7325
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5564 - accuracy: 0.7332
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5558 - accuracy: 0.7327
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7326
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5547 - accuracy: 0.7326
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5542 - accuracy: 0.7333
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7334
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7336
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7338
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5527 - accuracy: 0.7329
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7338
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5518 - accuracy: 0.7342
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5517 - accuracy: 0.7339
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7338
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7343
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5508 - accuracy: 0.7338
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7338
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7336
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7343
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5499 - accuracy: 0.7341
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7339
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7338
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5491 - accuracy: 0.7336
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7345
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7350
# Epoch 39/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7334
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5486 - accuracy: 0.7346
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7344
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7340
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7341
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5482 - accuracy: 0.7339
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7346
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7337
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7345
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7350
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7344
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7343
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5473 - accuracy: 0.7343
# Epoch 52/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7343
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7345
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7347
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5469 - accuracy: 0.7341
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7348
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7348
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7345
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7349
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5463 - accuracy: 0.7352
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7345
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7352
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7347
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7355
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7361
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5459 - accuracy: 0.7354
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5458 - accuracy: 0.7356
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7358
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7355
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7350
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7354
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7357
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7368
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7359
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7359
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5454 - accuracy: 0.7357
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7357
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7362
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7364
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7365
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7365
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5452 - accuracy: 0.7358
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7359
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7357
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7372
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7363
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7362
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7366
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7367
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7363
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7357
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5449 - accuracy: 0.7358
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7366
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5449 - accuracy: 0.7360
# Epoch 95/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5447 - accuracy: 0.7362
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7361
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7363
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7359
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7359
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7365

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5545 - accuracy: 0.7261 - 469ms/epoch - 2ms/step
# Loss: 0.5545337796211243, Accuracy: 0.726064145565033

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save("AlphabetSoupCharity_Optimzation2.h5")
